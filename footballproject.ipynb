# %%
# Out:
# Missing Values in Each Column:
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64
# Number of tuples: 42650
# Number of tournaments: 120
# Number of matches played in 2018: 908
# Home Wins: 20739
# Home Losses: 12074
# Home Draws: 9837
# Error during Git operations: Command '['git', 'add', '.']' returned non-zero exit status 128.
